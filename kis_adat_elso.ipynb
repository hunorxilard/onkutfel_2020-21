# %% [markdown]
# <a href="https://colab.research.google.com/github/hunorxilard/onkutfel_2020-21/blob/szili_dolga/onkut_gitver_1_szili_12_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls -l

# %%
# !wget https://github.com/hunorxilard/onkutfel_2020-21/blob/szili_dolga/real_and_fake_face_small.zip?raw=true

# %%
# !unzip ./real_and_fake_face_small.zip?raw=true

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
DATADIR = "/content/real_and_fake_face_small"
CATEGORIES = ["training_fake","training_real"]

# %%
for category in CATEGORIES:
  path=os.path.join(DATADIR,category)
  for img in os.listdir(path):
    print(str(os.path.join(path,img)))
    img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
    plt.imshow(img_array,cmap='gray')
    plt.show()
    break
  break
# Out:
# /content/real_and_fake_face_small/training_fake/mid_415_1111.jpg

# %%
training_data = []

def create_training_data():
  for category in CATEGORIES:
    path=os.path.join(DATADIR,category)
    class_num = CATEGORIES.index(category)
    for img in os.listdir(path):
      img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
      training_data.append([img_array,class_num])

create_training_data()

# %%
print(len(training_data))
# Out:
# 2040

# %%
import random

random.shuffle(training_data)

# %%
X=[]
y=[]

# %%
for features, label in training_data:
  X.append(features)
  y.append(label)

X=np.array(X).reshape(-1,150,150,1)

# %%
import pickle

pickle_out = open("X_pickle","wb")
pickle.dump(X,pickle_out)
pickle_out.close()

pickle_out = open("y_pickle","wb")
pickle.dump(y,pickle_out)
pickle_out.close()
